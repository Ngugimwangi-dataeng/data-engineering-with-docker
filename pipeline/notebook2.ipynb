# %%
import pandas as pd

# %%
prefix = 'https://github.com/DataTalksClub/nyc-tlc-data/releases/download/yellow/'
df = pd.read_csv(prefix + 'yellow_tripdata_2021-01.csv.gz')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 prefix = 'https://github.com/DataTalksClub/nyc-tlc-data/releases/download/yellow/'
# ----> 2 df = pd.read_csv(prefix + 'yellow_tripdata_2021-01.csv.gz')
#
# NameError: name 'pd' is not defined

# %%
df.head(n=0).to_sql(name='yellow_taxi_data', con=engine, if_exists='replace')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df.head(n=0).to_sql(name='yellow_taxi_data', con=engine, if_exists='replace')
#
# NameError: name 'df' is not defined
